# %% [markdown]
# This is a starter notebook for the project, you'll have to import the libraries you'll need, you can find a list of the ones available in this workspace in the requirements.txt file in this workspace.

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas
#   Downloading pandas-2.2.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 64.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.24.3)
# Collecting tzdata>=2022.7
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 32.7 MB/s eta 0:00:00
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: tzdata, pandas
# Successfully installed pandas-2.2.2 tzdata-2024.1

# %%
import os

os.environ["OPENAI_API_KEY"] = "<YOUR API KEY>"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
# from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.prompts import PromptTemplate
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.document_loaders.csv_loader import CSVLoader
import pandas as pd

# %%
model_name = 'gpt-3.5-turbo'
llm = ChatOpenAI(model=model_name, temperature=0,max_tokens=2000)

# %% [markdown]
# ### Synthetic Data Generation
# ### (No need to run this section again as synthetic data has already been generated and saved to csv file here: data/property_listings.csv)

# %%
prompt_template = """Generate {num_listings}  Property listings in csv format. Each listing must contain these fields in the csv:
 Location, Price, Size in Sqft, Number of Bedrooms, Number of Bathrooms, Property Age. Generate multiple listings for each location with varying Property sizes.
Only csv format is acceptable. Use semicolon as a separator.
"""

synthetic_data_prompt = PromptTemplate.from_template(prompt_template)

# %%
listings = llm.predict(synthetic_data_prompt.format(num_listings=25))

# %%
# Save Synthetic data as csv file
with open('data/property_listings.csv', 'w') as f:
    f.write(listings)

# %% [markdown]
# ### Loading Generated Synthetic data

# %%
# validating the csv in schema in pandas (Note we have to install pandas to run this cell)
df = pd.read_csv('data/property_listings.csv', sep=';')
df
# Out:
#          Location    Price  Size in Sqft  Number of Bedrooms  \
# 0        New York  1000000          1500                   3
# 1        New York  1500000          2000                   4
# 2        New York   800000          1200                   2
# 3        New York  1200000          1800                   3
# 4        New York   900000          1300                   2
# 5     Los Angeles   900000          1800                   3
# 6     Los Angeles  1200000          2500                   4
# 7     Los Angeles   750000          1500                   2
# 8     Los Angeles  1100000          2000                   3
# 9     Los Angeles   850000          1600                   2
# 10        Chicago   800000          2000                   3
# 11        Chicago  1100000          2500                   4
# 12        Chicago   700000          1500                   2
# 13        Chicago   950000          1800                   3
# 14        Chicago   750000          1400                   2
# 15          Miami  1200000          1800                   3
# 16          Miami  1500000          2500                   4
# 17          Miami  1000000          1500                   2
# 18          Miami  1300000          2000                   3
# 19          Miami   900000          1300                   2
# 20  San Francisco  2000000          2500                   4
# 21  San Francisco  1800000          2000                   3
# 22  San Francisco  1500000          1800                   2
# 23  San Francisco  2200000          3000                   5
# 24  San Francisco  1700000          2200                   3
#
#     Number of Bathrooms  Property Age
# 0                     2             5
# 1                     3            10
# 2                     1             2
# 3                     2             7
# 4                     1             4
# 5                     2             8
# 6                     3            12
# 7                     1             5
# 8                     2            10
# 9                     1             6
# 10                    2            15
# 11                    3            20
# 12                    1            10
# 13                    2            18
# 14                    1            12
# 15                    2             5
# 16                    3             8
# 17                    1             3
# 18                    2             6
# 19                    1             4
# 20                    3            10
# 21                    2             8
# 22                    1             5
# 23                    4            12
# 24                    2             7

# %%
# Loading Generated Synthetic data
loader = CSVLoader(file_path='data/property_listings.csv')
docs = loader.load()

# %%
docs
# Out:
# [Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: New York;1000000;1500;3;2;5', metadata={'source': 'data/property_listings.csv', 'row': 0}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: New York;1500000;2000;4;3;10', metadata={'source': 'data/property_listings.csv', 'row': 1}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: New York;800000;1200;2;1;2', metadata={'source': 'data/property_listings.csv', 'row': 2}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: New York;1200000;1800;3;2;7', metadata={'source': 'data/property_listings.csv', 'row': 3}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: New York;900000;1300;2;1;4', metadata={'source': 'data/property_listings.csv', 'row': 4}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Los Angeles;900000;1800;3;2;8', metadata={'source': 'data/property_listings.csv', 'row': 5}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Los Angeles;1200000;2500;4;3;12', metadata={'source': 'data/property_listings.csv', 'row': 6}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Los Angeles;750000;1500;2;1;5', metadata={'source': 'data/property_listings.csv', 'row': 7}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Los Angeles;1100000;2000;3;2;10', metadata={'source': 'data/property_listings.csv', 'row': 8}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Los Angeles;850000;1600;2;1;6', metadata={'source': 'data/property_listings.csv', 'row': 9}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Chicago;800000;2000;3;2;15', metadata={'source': 'data/property_listings.csv', 'row': 10}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Chicago;1100000;2500;4;3;20', metadata={'source': 'data/property_listings.csv', 'row': 11}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Chicago;700000;1500;2;1;10', metadata={'source': 'data/property_listings.csv', 'row': 12}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Chicago;950000;1800;3;2;18', metadata={'source': 'data/property_listings.csv', 'row': 13}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Chicago;750000;1400;2;1;12', metadata={'source': 'data/property_listings.csv', 'row': 14}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Miami;1200000;1800;3;2;5', metadata={'source': 'data/property_listings.csv', 'row': 15}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Miami;1500000;2500;4;3;8', metadata={'source': 'data/property_listings.csv', 'row': 16}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Miami;1000000;1500;2;1;3', metadata={'source': 'data/property_listings.csv', 'row': 17}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Miami;1300000;2000;3;2;6', metadata={'source': 'data/property_listings.csv', 'row': 18}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: Miami;900000;1300;2;1;4', metadata={'source': 'data/property_listings.csv', 'row': 19}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: San Francisco;2000000;2500;4;3;10', metadata={'source': 'data/property_listings.csv', 'row': 20}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: San Francisco;1800000;2000;3;2;8', metadata={'source': 'data/property_listings.csv', 'row': 21}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: San Francisco;1500000;1800;2;1;5', metadata={'source': 'data/property_listings.csv', 'row': 22}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: San Francisco;2200000;3000;5;4;12', metadata={'source': 'data/property_listings.csv', 'row': 23}),
#  Document(page_content='Location;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age: San Francisco;1700000;2200;3;2;7', metadata={'source': 'data/property_listings.csv', 'row': 24})]

# %% [markdown]
# ### Semantic search on Vector DB

# %%
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
split_docs = splitter.split_documents(docs)

embeddings = OpenAIEmbeddings()

db = Chroma.from_documents(split_docs, embeddings)

# %%
queries = [
    """Show me some properties in San Francisco.""",
    """Find me top properties in Miami with atleast 3 bedrooms.""",
    """Recommend properties in New York not older than 5 years""",
    
    
    
    
]


top_n_results = 3

# %%
def get_search_results(queries):
    answers = []
    for query in queries:
        answer = db.similarity_search(query,k=top_n_results)
        answers.append(answer)
        
    return answers

# %%
answers = get_search_results(queries)

# %% [markdown]
# ### Augmented Response Generation

# %%
def get_personalized_recommendations(answer):
    
    augmented_query = f"""Give me a personalized property listing based on my preferences: {answer}
    Use creative language to decsribe the property elaborately but Do not include any information beyond the provided information. 
    """
    augmented_response = llm.predict(augmented_query)
    
    return augmented_response

# %%
for i,answer in enumerate(answers):
    
    augmented_response = get_personalized_recommendations(answer)
    print(f'Query {i+1}:\n {queries[i]}\n')
    print(f'Response {i+1}:\n {augmented_response}\n')
    print('_________________________________________')
# Out:
# Query 1:
#  Show me some properties in San Francisco.
#
# Response 1:
#  Welcome to your dream home in San Francisco! This stunning property boasts 2500 sqft of luxurious living space, featuring 4 spacious bedrooms and 3 beautifully appointed bathrooms. With a price tag of $2,000,000, this home offers the perfect blend of elegance and comfort. The property is just 10 years old, ensuring modern amenities and a contemporary design. Don't miss out on this rare opportunity to own a piece of paradise in the heart of San Francisco.
#
# Alternatively, you may also consider a charming 3-bedroom, 2-bathroom home in San Francisco. Priced at $1,800,000, this cozy property offers 2000 sqft of living space and is perfect for those seeking a more intimate setting. With a property age of 8 years, this home combines modern convenience with classic charm. Don't let this gem slip through your fingers!
#
# Looking for a blend of style and affordability? Look no further than this 3-bedroom, 2-bathroom property in San Francisco. Priced at $1,700,000, this home offers 2200 sqft of living space and is perfect for those who appreciate a balance of comfort and elegance. With a property age of 7 years, this home is sure to impress even the most discerning buyer. Don't wait, schedule a viewing today and make this property your own!
#
# _________________________________________
# Query 2:
#  Find me top properties in Miami with atleast 3 bedrooms.
#
# Response 2:
#  Welcome to your dream home in Miami! This stunning property boasts 2500 sqft of luxurious living space, featuring 4 spacious bedrooms and 3 modern bathrooms. With a property age of 8 years, you can rest assured that this home has been well-maintained and is ready for you to move in. Priced at $1,500,000, this is a rare opportunity to own a piece of paradise in Miami.
#
# If you're looking for something a bit cozier, we also have a charming 3 bedroom, 2 bathroom home with 1800 sqft of space. This property, priced at $1,200,000, is perfect for those seeking a more intimate living experience in the heart of Miami.
#
# For those looking for a starter home or a smaller space, we have a lovely 2 bedroom, 1 bathroom property with 1500 sqft of living space. Priced at $1,000,000, this home is ideal for those looking to get their foot in the door of the Miami real estate market.
#
# No matter your preference, we have the perfect property for you in Miami. Don't miss out on these incredible opportunities to own a piece of paradise in this vibrant city. Contact us today to schedule a viewing!
#
# _________________________________________
# Query 3:
#  Recommend properties in New York not older than 5 years
#
# Response 3:
#  Welcome to your dream home in New York! This stunning property boasts 1500 square feet of luxurious living space, featuring 3 spacious bedrooms and 2 beautifully appointed bathrooms. With a price tag of $1,000,000, this home offers the perfect blend of elegance and comfort. The property is just 5 years old, ensuring modern amenities and a fresh, contemporary feel. Don't miss out on this incredible opportunity to own a piece of paradise in the heart of New York City. Contact us today to schedule a viewing!
#
# _________________________________________
