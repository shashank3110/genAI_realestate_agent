# %% [markdown]
# This is a starter notebook for the project, you'll have to import the libraries you'll need, you can find a list of the ones available in this workspace in the requirements.txt file in this workspace.

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /home/student/.local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /home/student/.local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.22.4 in /opt/conda/lib/python3.10/site-packages (from pandas) (1.24.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import os

os.environ["OPENAI_API_KEY"] = "<YOUR API KEY>"
os.environ["OPENAI_API_BASE"] = "https://openai.vocareum.com/v1"

# %%
# from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.vectorstores import Chroma
from langchain.prompts import PromptTemplate
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.document_loaders.csv_loader import CSVLoader
import pandas as pd

# %%
model_name = 'gpt-3.5-turbo'
llm = ChatOpenAI(model=model_name, temperature=0,max_tokens=2000)

# %% [markdown]
# ### Synthetic Data Generation
# ### (No need to run this section again as synthetic data has already been generated and saved to csv file here: data/property_listings.csv)

# %%
prompt_template = """Generate {num_listings}  Property listings in csv format. Each listing must contain these fields in the csv:
 Neighborhood, Price, Size in Sqft, Number of Bedrooms, Number of Bathrooms, Property Age, Description, Neighborhood Description. Generate multiple listings for each location with varying Property sizes.
Only csv format is acceptable. Use semicolon as a separator.
"""

synthetic_data_prompt = PromptTemplate.from_template(prompt_template)

# %%
listings = llm.predict(synthetic_data_prompt.format(num_listings=25))

# %%
# Save Synthetic data as csv file
with open('data/property_listings.csv', 'w') as f:
    f.write(listings)

# %% [markdown]
# ### Loading Generated Synthetic data

# %%
# validating the csv in schema in pandas (Note we have to install pandas to run this cell)
df = pd.read_csv('data/property_listings.csv', sep=';')
df
# Out:
#    Neighborhood    Price  Size in Sqft  Number of Bedrooms  \
# 0      Downtown   500000          1000                   2
# 1      Downtown   750000          1500                   3
# 2      Downtown  1000000          2000                   4
# 3      Downtown   600000          1200                   2
# 4      Downtown   900000          1800                   3
# 5       Midtown   450000           900                   2
# 6       Midtown   650000          1300                   3
# 7       Midtown   800000          1600                   4
# 8       Midtown   550000          1100                   2
# 9       Midtown   750000          1500                   3
# 10       Uptown   700000          1400                   3
# 11       Uptown   950000          1900                   4
# 12       Uptown  1200000          2400                   5
# 13       Uptown   800000          1600                   3
# 14       Uptown  1100000          2200                   4
# 15     West End   400000           800                   2
# 16     West End   600000          1200                   3
# 17     West End   750000          1500                   4
# 18     West End   500000          1000                   2
# 19     West End   700000          1400                   3
#
#     Number of Bathrooms  Property Age  \
# 0                     1             5
# 1                     2            10
# 2                     3            15
# 3                     2             8
# 4                     2            12
# 5                     1             7
# 6                     2            12
# 7                     3            20
# 8                     2            10
# 9                     2            15
# 10                    2            10
# 11                    3            18
# 12                    4            25
# 13                    2            12
# 14                    3            20
# 15                    1             5
# 16                    2            10
# 17                    3            15
# 18                    2             8
# 19                    2            12
#
#                                           Description  \
# 0                 Cozy condo in the heart of the city
# 1                       Spacious loft with city views
# 2            Luxurious penthouse with rooftop terrace
# 3                       Modern apartment with balcony
# 4             Renovated townhouse with private garden
# 5             Charming bungalow with original details
# 6          Contemporary townhome with open floor plan
# 7            Colonial-style house with large backyard
# 8                   Cozy cottage with updated kitchen
# 9                      Modern condo with rooftop deck
# 10               Spacious duplex with hardwood floors
# 11           Victorian mansion with original features
# 12      Custom-built estate with pool and guest house
# 13        Contemporary townhouse with rooftop terrace
# 14                Luxurious penthouse with city views
# 15             Cozy ranch-style home with fenced yard
# 16  Renovated craftsman bungalow with modern ameni...
# 17     Spacious colonial house with wrap-around porch
# 18               Modern townhome with attached garage
# 19                    Contemporary condo with balcony
#
#                              Neighborhood Description
# 0   Vibrant neighborhood with plenty of restaurant...
# 1        Close to public transportation and nightlife
# 2               Walking distance to parks and museums
# 3   Convenient location near grocery stores and cafes
# 4       Historic neighborhood with tree-lined streets
# 5              Family-friendly area with good schools
# 6          Close to shopping centers and public parks
# 7          Quiet neighborhood with tree-lined streets
# 8           Walking distance to restaurants and cafes
# 9   Close to public transportation and entertainme...
# 10  Upscale neighborhood with luxury boutiques and...
# 11            Close to parks and cultural attractions
# 12        Exclusive neighborhood with gated entrances
# 13     Walking distance to shopping and entertainment
# 14  Close to public transportation and upscale res...
# 15     Family-friendly neighborhood with good schools
# 16               Close to parks and community centers
# 17         Quiet neighborhood with tree-lined streets
# 18         Close to shopping centers and public parks
# 19          Walking distance to restaurants and cafes

# %%
# Loading Generated Synthetic data
loader = CSVLoader(file_path='data/property_listings.csv')
docs = loader.load()

# %%
docs
# Out:
# [Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Downtown;500000;1000;2;1;5;Cozy condo in the heart of the city;Vibrant neighborhood with plenty of restaurants and shops', metadata={'source': 'data/property_listings.csv', 'row': 0}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Downtown;750000;1500;3;2;10;Spacious loft with city views;Close to public transportation and nightlife', metadata={'source': 'data/property_listings.csv', 'row': 1}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Downtown;1000000;2000;4;3;15;Luxurious penthouse with rooftop terrace;Walking distance to parks and museums', metadata={'source': 'data/property_listings.csv', 'row': 2}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Downtown;600000;1200;2;2;8;Modern apartment with balcony;Convenient location near grocery stores and cafes', metadata={'source': 'data/property_listings.csv', 'row': 3}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Downtown;900000;1800;3;2;12;Renovated townhouse with private garden;Historic neighborhood with tree-lined streets', metadata={'source': 'data/property_listings.csv', 'row': 4}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Midtown;450000;900;2;1;7;Charming bungalow with original details;Family-friendly area with good schools', metadata={'source': 'data/property_listings.csv', 'row': 5}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Midtown;650000;1300;3;2;12;Contemporary townhome with open floor plan;Close to shopping centers and public parks', metadata={'source': 'data/property_listings.csv', 'row': 6}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Midtown;800000;1600;4;3;20;Colonial-style house with large backyard;Quiet neighborhood with tree-lined streets', metadata={'source': 'data/property_listings.csv', 'row': 7}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Midtown;550000;1100;2;2;10;Cozy cottage with updated kitchen;Walking distance to restaurants and cafes', metadata={'source': 'data/property_listings.csv', 'row': 8}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Midtown;750000;1500;3;2;15;Modern condo with rooftop deck;Close to public transportation and entertainment venues', metadata={'source': 'data/property_listings.csv', 'row': 9}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Uptown;700000;1400;3;2;10;Spacious duplex with hardwood floors;Upscale neighborhood with luxury boutiques and fine dining', metadata={'source': 'data/property_listings.csv', 'row': 10}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Uptown;950000;1900;4;3;18;Victorian mansion with original features;Close to parks and cultural attractions', metadata={'source': 'data/property_listings.csv', 'row': 11}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Uptown;1200000;2400;5;4;25;Custom-built estate with pool and guest house;Exclusive neighborhood with gated entrances', metadata={'source': 'data/property_listings.csv', 'row': 12}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Uptown;800000;1600;3;2;12;Contemporary townhouse with rooftop terrace;Walking distance to shopping and entertainment', metadata={'source': 'data/property_listings.csv', 'row': 13}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: Uptown;1100000;2200;4;3;20;Luxurious penthouse with city views;Close to public transportation and upscale restaurants', metadata={'source': 'data/property_listings.csv', 'row': 14}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: West End;400000;800;2;1;5;Cozy ranch-style home with fenced yard;Family-friendly neighborhood with good schools', metadata={'source': 'data/property_listings.csv', 'row': 15}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: West End;600000;1200;3;2;10;Renovated craftsman bungalow with modern amenities;Close to parks and community centers', metadata={'source': 'data/property_listings.csv', 'row': 16}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: West End;750000;1500;4;3;15;Spacious colonial house with wrap-around porch;Quiet neighborhood with tree-lined streets', metadata={'source': 'data/property_listings.csv', 'row': 17}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: West End;500000;1000;2;2;8;Modern townhome with attached garage;Close to shopping centers and public parks', metadata={'source': 'data/property_listings.csv', 'row': 18}),
#  Document(page_content='Neighborhood;Price;Size in Sqft;Number of Bedrooms;Number of Bathrooms;Property Age;Description;Neighborhood Description: West End;700000;1400;3;2;12;Contemporary condo with balcony;Walking distance to restaurants and cafes', metadata={'source': 'data/property_listings.csv', 'row': 19})]

# %% [markdown]
# ### Semantic search on Vector DB

# %%
splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
split_docs = splitter.split_documents(docs)

embeddings = OpenAIEmbeddings()

db = Chroma.from_documents(split_docs, embeddings)

# %%
queries = [
    """Show me some properties in Midtown.""",
    """Find me top properties in West End with atleast 3 bedrooms.""",
    """Recommend properties in Downtown not older than 5 years""",
      
]


top_n_results = 3

# %%
def get_search_results(queries):
    answers = []
    for query in queries:
        answer = db.similarity_search(query,k=top_n_results)
        answers.append(answer)
        
    return answers

# %%
answers = get_search_results(queries)

# %% [markdown]
# ### Augmented Response Generation

# %%
def get_personalized_recommendations(answer):
    
    augmented_query = f"""Give me a personalized property listing based on my preferences: {answer}
    Use creative language to describe the property elaborately using all the provided information (price, size, etc.) according my above preferences but Do not include any information beyond the provided information.
    """
    augmented_response = llm.predict(augmented_query)
    
    return augmented_response

# %%
for i,answer in enumerate(answers):
    
    augmented_response = get_personalized_recommendations(answer)
    print(f'Query {i+1}:\n {queries[i]}\n')
